# %% [markdown]
# <a href="https://colab.research.google.com/github/coltongerth/Mimic3-viz/blob/main/MIMIC3_Viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade chart_studio
# Out:
# Collecting chart_studio
#   Downloading chart_studio-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from chart_studio) (5.24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from chart_studio) (2.32.3)
# Collecting retrying>=1.3.3 (from chart_studio)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from chart_studio) (1.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->chart_studio) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly->chart_studio) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->chart_studio) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->chart_studio) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->chart_studio) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->chart_studio) (2024.12.14)
# Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 3.1 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Installing collected packages: retrying, chart_studio
# Successfully installed chart_studio-1.1.0 retrying-1.3.4

# %%
from google.colab import files, data_table
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.optimize
import chart_studio
import chart_studio.plotly as py
import plotly.graph_objects as go
import plotly.io as pio
import plotly.express as px

data_table.enable_dataframe_formatter()

# %%
#@title Provide Google Credentials to Colab Runtime (May Require Manually Copy/Pasting Authentication Code)
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
project_id = 'ai-in-healthcare-449320' #@param{type:"string"}

# Package used for interfacing w/ BigQuery from Python
from google.cloud import bigquery

# Create BigQuery client
bq_client = bigquery.Client(project = project_id)

# %% [markdown]
# First Visualization: Basic Patient Insurance Ratios using Plotly's Pie-chart.

# %%
query = """
SELECT
  subject_id,
  insurance,
FROM `physionet-data.mimiciii_clinical.patients`
JOIN `physionet-data.mimiciii_clinical.admissions` USING (subject_id)

"""

df = bq_client.query(query).to_dataframe()
df
# Out:
# Warning: total number of rows (58976) exceeds max_rows (20000). Falling back to pandas display.
#        subject_id   insurance
# 0           18333     Private
# 1            7730     Private
# 2           11670     Private
# 3            8060     Private
# 4            8060     Private
# ...           ...         ...
# 58971       70330  Government
# 58972       70339  Government
# 58973       77623  Government
# 58974       43837  Government
# 58975       43878  Government
#
# [58976 rows x 2 columns]

# %%
insurance_counts = df['insurance'].value_counts().reset_index()
insurance_counts.columns = ['insurance', 'Count']

fig = px.pie(insurance_counts, names='insurance', values='Count',
             title='Insurance Distribution in ICU Patients')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fac243c8-0759-4f99-ab15-42692e31a903" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fac243c8-0759-4f99-ab15-42692e31a903")) {                    Plotly.newPlot(                        "fac243c8-0759-4f99-ab15-42692e31a903",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"insurance=%{label}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Medicare","Private","Medicaid","Government","Self Pay"],"legendgroup":"","name":"","showlegend":true,"values":[28215,22582,5785,1783,611],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar" ...

# %% [markdown]
# Second Visualization: Comparison of Drug Induced Mortalities by Gender using Plotly's Bar-chart.

# %%
query = """
SELECT
  row_id,
  gender,
  drg_mortality
FROM `physionet-data.mimiciii_clinical.patients`
JOIN `physionet-data.mimiciii_clinical.drgcodes` USING (row_id)

"""

df = bq_client.query(query).to_dataframe()
df
# Out:
# Warning: total number of rows (46520) exceeds max_rows (20000). Falling back to pandas display.
#        row_id gender  drg_mortality
# 0       41451      M              0
# 1          49      F           <NA>
# 2       17808      F           <NA>
# 3       17328      F           <NA>
# 4        7313      F           <NA>
# ...       ...    ...            ...
# 46515   31750      M              4
# 46516   31763      M              4
# 46517   31769      M              4
# 46518   31832      M              4
# 46519   31840      M              4
#
# [46520 rows x 3 columns]

# %%
df['drg_mortality_na'] = df['drg_mortality'].isna()
gender_counts = df.groupby(['gender', 'drg_mortality_na']).size().reset_index(name='count')
gender_counts['drg_mortality_na'] = gender_counts['drg_mortality_na'].map({True: 'Non-Mortality', False: 'Mortality'})

fig = px.bar(
    gender_counts,
    x='gender',
    y='count',
    color='drg_mortality_na',
    color_discrete_map={'Mortality': 'red', 'Non-Mortality': 'blue'},
    barmode='group',
    title='Comparison of Drug Induced Mortalities by Gender',
    labels={'count': 'Patient Count', 'gender': 'Gender', 'drg_mortality_na': 'DRG Mortality'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a8a02438-e5d0-4c90-b689-b05720c9e09a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8a02438-e5d0-4c90-b689-b05720c9e09a")) {                    Plotly.newPlot(                        "a8a02438-e5d0-4c90-b689-b05720c9e09a",                        [{"alignmentgroup":"True","hovertemplate":"DRG Mortality=Mortality\u003cbr\u003eGender=%{x}\u003cbr\u003ePatient Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mortality","marker":{"color":"red","pattern":{"shape":""}},"name":"Mortality","offsetgroup":"Mortality","orientation":"v","showlegend":true,"textposition":"auto","x":["F","M"],"xaxis":"x","y":[6125,7828],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"DRG Mortality=Non-Mortality\u003cbr\u003eGender=%{x}\u003cbr\u003ePatient Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Non-Mortality","marker":{"color":"blue","pattern":{"shape":""}},"name":"Non-Mortality","offsetgroup":"Non-Mortality","orientation":"v","showlegend":true,"textposition":"auto","x":["F","M"],"xaxis":"x","y":[14274,18293],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"sca ...

# %% [markdown]
# Third Visualization: ICU Length of Stay vs Age using Plotly's Scatter Plot.

# %%
query = """
SELECT
  subject_id,
  los,
  DATE_DIFF(DATE(admittime), DATE(dob), YEAR) AS age
FROM `physionet-data.mimiciii_clinical.patients`
JOIN `physionet-data.mimiciii_clinical.icustays` USING (subject_id)
JOIN `physionet-data.mimiciii_clinical.admissions` USING (subject_id)
WHERE DATE_DIFF(DATE(admittime), DATE(dob), YEAR) BETWEEN 1 AND 100
"""

df = bq_client.query(query).to_dataframe()
df
# Out:
# Warning: total number of rows (103027) exceeds max_rows (20000). Falling back to pandas display.
#         subject_id      los  age
# 0            27595  10.9331   32
# 1            31263   4.7062   18
# 2            27617   2.4125   19
# 3            27617   2.4125   19
# 4            27394  10.4183   22
# ...            ...      ...  ...
# 103022       77227   9.2669   88
# 103023       94221   1.9663   88
# 103024       93062   2.8454   88
# 103025       90296   1.8373   88
# 103026       96137   0.8634   88
#
# [103027 rows x 3 columns]

# %%
df['los'] = pd.to_numeric(df['los'], errors='coerce')
df['age'] = pd.to_numeric(df['age'], errors='coerce')

fig = px.scatter(
    df,
    x='age',
    y='los',
    title="ICU Length of Stay vs Age",
    labels={'age': 'Age (Years)', 'los': 'Length of Stay (Days)'},
    opacity=0.6
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3273bafe-6fd9-45d7-b17a-8fb4c1c4eef4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3273bafe-6fd9-45d7-b17a-8fb4c1c4eef4")) {                    Plotly.newPlot(                        "3273bafe-6fd9-45d7-b17a-8fb4c1c4eef4",                        [{"hovertemplate":"Age (Years)=%{x}\u003cbr\u003eLength of Stay (Days)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.6,"symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[32,18,19,19,22,22,22,18,27,32,30,29,30,89,18,89,22,28,26,89,89,20,27,31,22,32,27,32,30,31,31,29,29,32,27,31,31,20,20,22,22,22,26,26,27,20,26,27,20,20,20,27,28,28,27,89,31,31,89,89,89,26,28,29,32,22,26,89,29,32,32,30,30,31,31,26,28,28,30,31,32,32,32,27,30,31,19,19,19,19,20,20,32,89,27,30,31,32,32,28,30,31,31,30,28,89,27,26,19,32,32,32,32,29,19,89,89,26,27,89,22,89,26,19,31,89,26,28,18,28,29,29,32,27,26,30,19,29,29,31,31,29,30,19,28,29,26,32,26,32,32,22,32,28,31,31,31,31,32,32,31,28,27,89,20,20,32,22,22,22,32,32,28,27,18,29,22,22,22,22,19,31,26,32,89,28,18,89,89,89,32,32,26,29,29,30,32,32,30,32,28,28,28,89,89,31,89,28,30,29,89,29,32,30,29,18,18,30,31,30,19,31,20,20,22,22,22,26,26,27,20,26,27,20,20,20,27,28,28,27,29,29,20,32,29,29,20,20,22,22,22,26,26,27,20,26,27,20,20,20,27,28,28,27,20,20,22,22,22,26,26,27,20,26,27,20,20,20,27,28,28,27
# 0      EMERGENCY      F  18634
# 1       ELECTIVE      F   3174
# 2         URGENT      F    600
# 3        NEWBORN      F   3618
# 4      EMERGENCY      M  23437
# 5       ELECTIVE      M   4532
# 6         URGENT      M    736
# 7        NEWBORN      M   4245

# %%
import plotly.express as px

fig = px.sunburst(
    df,
    path=['admission_type', 'gender'],
    values='count',
    title="ICU Admission Breakdown by Type and Gender",
    color='admission_type',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ffaf2f7d-eaf5-4c9e-ab28-9db31214aa98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffaf2f7d-eaf5-4c9e-ab28-9db31214aa98")) {                    Plotly.newPlot(                        "ffaf2f7d-eaf5-4c9e-ab28-9db31214aa98",                        [{"branchvalues":"total","customdata":[["EMERGENCY"],["EMERGENCY"],["ELECTIVE"],["ELECTIVE"],["URGENT"],["URGENT"],["NEWBORN"],["NEWBORN"],["ELECTIVE"],["EMERGENCY"],["NEWBORN"],["URGENT"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eadmission_type=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["EMERGENCY\u002fF","EMERGENCY\u002fM","ELECTIVE\u002fF","ELECTIVE\u002fM","URGENT\u002fF","URGENT\u002fM","NEWBORN\u002fF","NEWBORN\u002fM","ELECTIVE","EMERGENCY","NEWBORN","URGENT"],"labels":["F","M","F","M","F","M","F","M","ELECTIVE","EMERGENCY","NEWBORN","URGENT"],"marker":{"colors":["#636efa","#636efa","#EF553B","#EF553B","#00cc96","#00cc96","#ab63fa","#ab63fa","#EF553B","#636efa","#ab63fa","#00cc96"]},"name":"","parents":["EMERGENCY","EMERGENCY","ELECTIVE","ELECTIVE","URGENT","URGENT","NEWBORN","NEWBORN","","","",""],"values":[18634,23437,3174,4532,600,736,3618,4245,7706,42071,7863,1336],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778, ...

# %% [markdown]
# Fifth Visualization: ICU Length of Stay by Admission Type using Plotly's Box-Graph

# %%
query = """
SELECT
  admission_type,
  los
FROM `physionet-data.mimiciii_clinical.icustays`
JOIN `physionet-data.mimiciii_clinical.admissions` USING (subject_id)
WHERE los IS NOT NULL
"""

df = bq_client.query(query).to_dataframe()
df
# Out:
# Warning: total number of rows (116414) exceeds max_rows (20000). Falling back to pandas display.
#        admission_type     los
# 0           EMERGENCY  6.2559
# 1           EMERGENCY  6.2559
# 2           EMERGENCY  6.2559
# 3           EMERGENCY  2.3403
# 4              URGENT  3.5888
# ...               ...     ...
# 116409      EMERGENCY  0.8539
# 116410       ELECTIVE  0.8539
# 116411      EMERGENCY  1.1919
# 116412      EMERGENCY  1.1919
# 116413       ELECTIVE  0.9259
#
# [116414 rows x 2 columns]

# %%
fig = px.box(df, x='admission_type', y='los', title="ICU Length of Stay by Admission Type",
             labels={'los': 'Length of Stay (Days)', 'admission_type': 'Admission Type'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1313beba-878b-4b74-89f7-dfb760f8c87d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1313beba-878b-4b74-89f7-dfb760f8c87d")) {                    Plotly.newPlot(                        "1313beba-878b-4b74-89f7-dfb760f8c87d",                        [{"alignmentgroup":"True","hovertemplate":"Admission Type=%{x}\u003cbr\u003eLength of Stay (Days)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","URGENT","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","EMERGENCY","ELECTIVE","ELECTIVE","EMERGENCY","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","URGENT","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","URGENT","ELECTIVE","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","URGENT","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","URGENT","EMERGENCY","EMERGENCY","EMERGENCY","URGENT","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","ELECTIVE","EMERGENCY","EMERGENCY","URGENT","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","URGENT","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","ELECTIVE","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","EMERGENCY","ELECTIVE","EMERGENCY","EMERGENCY","EMERGENC ...
